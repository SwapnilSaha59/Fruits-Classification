# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os, PIL
from glob import glob
import tensorflow as tf
from io import StringIO 
from PIL import Image
import pydot
import imageio as iio
import cv2


import seaborn as sns
from sklearn import model_selection


import keras
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import  img_to_array
from tensorflow.keras.preprocessing.image import array_to_img


from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
""" Sequential Model Architecture """
Sequential = tf.keras.models.Sequential

""" Data Preprocessing Functions """
Resizing = tf.keras.layers.experimental.preprocessing.Resizing
Rescaling = tf.keras.layers.experimental.preprocessing.Rescaling

""" Data Augmentation Functions """
RandomFlip = tf.keras.layers.experimental.preprocessing.RandomFlip
RandomRotation = tf.keras.layers.experimental.preprocessing.RandomRotation
RandomZoom = tf.keras.layers.experimental.preprocessing.RandomZoom

""" Artificial Neural Network Layer Inventory """
Dense = tf.keras.layers.Dense
Dropout = tf.keras.layers.Dropout

""" Convolutional Neural Network Layer Inventory """
Conv2D = tf.keras.layers.Conv2D
MaxPool2D = tf.keras.layers.MaxPool2D
Flatten = tf.keras.layers.Flatten

""" Residual Network Layer Inventory """
ResNet50 = tf.keras.applications.resnet50.ResNet50

""" Function to Load Images from Target Folder """
get_image_data = tf.keras.utils.image_dataset_from_directory

# %%
path = '/home/manas/Desktop/ML/JU/Fruits'

# %%
path1 = '/home/manas/Desktop/ML/JU/Fruits/Bad Quality_Fruits/Apple_Bad'
path2 = '/home/manas/Desktop/ML/JU/Fruits/Good Quality_Fruits/Apple_Good'

# %%
path3 = '/home/manas/Desktop/ML/JU/Fruits/Bad Quality_Fruits/Banana_Bad'
path4 = '/home/manas/Desktop/ML/JU/Fruits/Good Quality_Fruits/Banana_Good'

# %%
path5 = '/home/manas/Desktop/ML/JU/Fruits/Bad Quality_Fruits/Guava_Bad'
path6 = '/home/manas/Desktop/ML/JU/Fruits/Good Quality_Fruits/Guava_Good'

# %%
path7 = '/home/manas/Desktop/ML/JU/Fruits/Bad Quality_Fruits/Lime_Bad'
path8 = '/home/manas/Desktop/ML/JU/Fruits/Good Quality_Fruits/Lime_Good'

# %%
path9 = '/home/manas/Desktop/ML/JU/Fruits/Bad Quality_Fruits/Orange_Bad'
path10 = '/home/manas/Desktop/ML/JU/Fruits/Good Quality_Fruits/Orange_Good'

# %%
path11 = '/home/manas/Desktop/ML/JU/Fruits/Bad Quality_Fruits/Pomegranate_Bad'
path12 = '/home/manas/Desktop/ML/JU/Fruits/Good Quality_Fruits/Pomegranate_Good'

# %%
Apple_Bad1 = f"{path1}/Apple_Bad1.jpg"
Apple_Bad2 = f"{path1}/Apple_Bad2.jpg"
Apple_Bad3 = f"{path1}/Apple_Bad3.jpg"
Apple_Bad4 = f"{path1}/Apple_Bad4.jpg"
Apple_Bad5 = f"{path1}/Apple_Bad5.jpg"
Apple_Bad6 = f"{path1}/Apple_Bad6.jpg"

# %%
Apple_Good1 = f"{path2}/Apple_Good1.jpg"
Apple_Good2 = f"{path2}/Apple_Good2.jpg"
Apple_Good3 = f"{path2}/Apple_Good3.jpg"
Apple_Good4 = f"{path2}/Apple_Good4.jpg"
Apple_Good5 = f"{path2}/Apple_Good5.jpg"
Apple_Good6 = f"{path2}/Apple_Good6.jpg"

# %%
Banana_Bad1 = f"{path3}/Banana_Bad1.jpg"
Banana_Bad2 = f"{path3}/Banana_Bad2.jpg"
Banana_Bad3 = f"{path3}/Banana_Bad3.jpg"
Banana_Bad4 = f"{path3}/Banana_Bad4.jpg"
Banana_Bad5 = f"{path3}/Banana_Bad5.jpg"
Banana_Bad6 = f"{path3}/Banana_Bad6.jpg"

# %%
Banana_Good1 = f"{path4}/Banana_Good1.jpg"
Banana_Good2 = f"{path4}/Banana_Good2.jpg"
Banana_Good3 = f"{path4}/Banana_Good3.jpg"
Banana_Good4 = f"{path4}/Banana_Good4.jpg"
Banana_Good5 = f"{path4}/Banana_Good5.jpg"
Banana_Good6 = f"{path4}/Banana_Good6.jpg"

# %%
Guava_Bad1 = f"{path5}/Guava_Bad1.jpg"
Guava_Bad2 = f"{path5}/Guava_Bad2.jpg"
Guava_Bad3 = f"{path5}/Guava_Bad3.jpg"
Guava_Bad4 = f"{path5}/Guava_Bad4.jpg"
Guava_Bad5 = f"{path5}/Guava_Bad5.jpg"
Guava_Bad6 = f"{path5}/Guava_Bad6.jpg"

# %%
Guava_Good1 = f"{path6}/Guava_Good1.jpg"
Guava_Good2 = f"{path6}/Guava_Good2.jpg"
Guava_Good3 = f"{path6}/Guava_Good3.jpg"
Guava_Good4 = f"{path6}/Guava_Good4.jpg"
Guava_Good5 = f"{path6}/Guava_Good5.jpg"
Guava_Good6 = f"{path6}/Guava_Good6.jpg"

# %%
Lime_Bad1 = f"{path7}/Lime_Bad1.jpg"
Lime_Bad2 = f"{path7}/Lime_Bad2.jpg"
Lime_Bad3 = f"{path7}/Lime_Bad3.jpg"
Lime_Bad4 = f"{path7}/Lime_Bad4.jpg"
Lime_Bad5 = f"{path7}/Lime_Bad5.jpg"
Lime_Bad6 = f"{path7}/Lime_Bad6.jpg"

# %%
Lime_Good1 = f"{path8}/Lime_Good1.jpg"
Lime_Good2 = f"{path8}/Lime_Good2.jpg"
Lime_Good3 = f"{path8}/Lime_Good3.jpg"
Lime_Good4 = f"{path8}/Lime_Good4.jpg"
Lime_Good5 = f"{path8}/Lime_Good5.jpg"
Lime_Good6 = f"{path8}/Lime_Good6.jpg"

# %%
Orange_Bad1 = f"{path9}/Orange_Bad1.jpg"
Orange_Bad2 = f"{path9}/Orange_Bad2.jpg"
Orange_Bad3 = f"{path9}/Orange_Bad3.jpg"
Orange_Bad4 = f"{path9}/Orange_Bad4.jpg"
Orange_Bad5 = f"{path9}/Orange_Bad5.jpg"
Orange_Bad6 = f"{path9}/Orange_Bad6.jpg"

# %%
Orange_Good1 = f"{path10}/Orange_Good1.jpg"
Orange_Good2 = f"{path10}/Orange_Good2.jpg"
Orange_Good3 = f"{path10}/Orange_Good3.jpg"
Orange_Good4 = f"{path10}/Orange_Good4.jpg"
Orange_Good5 = f"{path10}/Orange_Good5.jpg"
Orange_Good6 = f"{path10}/Orange_Good6.jpg"

# %%
Pomegranate_Bad1 = f"{path11}/Pomegranate_Bad1.jpg"
Pomegranate_Bad2 = f"{path11}/Pomegranate_Bad2.jpg"
Pomegranate_Bad3 = f"{path11}/Pomegranate_Bad3.jpg"
Pomegranate_Bad4 = f"{path11}/Pomegranate_Bad4.jpg"
Pomegranate_Bad5 = f"{path11}/Pomegranate_Bad5.jpg"
Pomegranate_Bad6 = f"{path11}/Pomegranate_Bad6.jpg"

# %%
Pomegranate_Good1 = f"{path12}/Pomegranate_Good1.jpg"
Pomegranate_Good2 = f"{path12}/Pomegranate_Good2.jpg"
Pomegranate_Good3 = f"{path12}/Pomegranate_Good3.jpg"
Pomegranate_Good4 = f"{path12}/Pomegranate_Good4.jpg"
Pomegranate_Good5 = f"{path12}/Pomegranate_Good5.jpg"
Pomegranate_Good6 = f"{path12}/Pomegranate_Good6.jpg"

# %%
print(f"{len(glob(Apple_Bad1))} Images of Apple_Bad1")
print(f"{len(glob(Apple_Bad2))} Images of Apple_Bad2")
print(f"{len(glob(Apple_Bad3))} Images of Apple_Bad3")
print(f"{len(glob(Apple_Bad4))} Images of Apple_Bad4")
print(f"{len(glob(Apple_Bad5))} Images of Apple_Bad5")
print(f"{len(glob(Apple_Bad6))} Images of Apple_Bad6")
# Out:
# 1 Images of Apple_Bad1
# 1 Images of Apple_Bad2
# 1 Images of Apple_Bad3
# 1 Images of Apple_Bad4
# 1 Images of Apple_Bad5
# 1 Images of Apple_Bad6

# %%
print(f"{len(glob(Apple_Good1))} Images of Apple_Good1")
print(f"{len(glob(Apple_Good2))} Images of Apple_Good2")
print(f"{len(glob(Apple_Good3))} Images of Apple_Good3")
print(f"{len(glob(Apple_Good4))} Images of Apple_Good4")
print(f"{len(glob(Apple_Good5))} Images of Apple_Good5")
print(f"{len(glob(Apple_Good6))} Images of Apple_Good6")
# Out:
# 1 Images of Apple_Good1
# 1 Images of Apple_Good2
# 1 Images of Apple_Good3
# 1 Images of Apple_Good4
# 1 Images of Apple_Good5
# 1 Images of Apple_Good6

# %%
print(f"{len(glob(Banana_Bad1))} Images of Banana_Bad1")
print(f"{len(glob(Banana_Bad2))} Images of Banana_Bad2")
print(f"{len(glob(Banana_Bad3))} Images of Banana_Bad3")
print(f"{len(glob(Banana_Bad4))} Images of Banana_Bad4")
print(f"{len(glob(Banana_Bad5))} Images of Banana_Bad5")
print(f"{len(glob(Banana_Bad6))} Images of Banana_Bad6")
# Out:
# 1 Images of Banana_Bad1
# 1 Images of Banana_Bad2
# 1 Images of Banana_Bad3
# 1 Images of Banana_Bad4
# 1 Images of Banana_Bad5
# 1 Images of Banana_Bad6

# %%
print(f"{len(glob(Banana_Good1))} Images of Banana_Good1")
print(f"{len(glob(Banana_Good2))} Images of Banana_Good2")
print(f"{len(glob(Banana_Good3))} Images of Banana_Good3")
print(f"{len(glob(Banana_Good4))} Images of Banana_Good4")
print(f"{len(glob(Banana_Good5))} Images of Banana_Good5")
print(f"{len(glob(Banana_Good6))} Images of Banana_Good6")
# Out:
# 1 Images of Banana_Good1
# 1 Images of Banana_Good2
# 1 Images of Banana_Good3
# 1 Images of Banana_Good4
# 1 Images of Banana_Good5
# 1 Images of Banana_Good6

# %%
print(f"{len(glob(Guava_Bad1))} Images of Guava_Bad1")
print(f"{len(glob(Guava_Bad2))} Images of Guava_Bad2")
print(f"{len(glob(Guava_Bad3))} Images of Guava_Bad3")
print(f"{len(glob(Guava_Bad4))} Images of Guava_Bad4")
print(f"{len(glob(Guava_Bad5))} Images of Guava_Bad5")
print(f"{len(glob(Guava_Bad6))} Images of Guava_Bad6")
# Out:
# 1 Images of Guava_Bad1
# 1 Images of Guava_Bad2
# 1 Images of Guava_Bad3
# 1 Images of Guava_Bad4
# 1 Images of Guava_Bad5
# 1 Images of Guava_Bad6

# %%
print(f"{len(glob(Guava_Good1))} Images of Guava_Good1")
print(f"{len(glob(Guava_Good2))} Images of Guava_Good2")
print(f"{len(glob(Guava_Good3))} Images of Guava_Good3")
print(f"{len(glob(Guava_Good4))} Images of Guava_Good4")
print(f"{len(glob(Guava_Good5))} Images of Guava_Good5")
print(f"{len(glob(Guava_Good6))} Images of Guava_Good6")
# Out:
# 1 Images of Guava_Good1
# 1 Images of Guava_Good2
# 1 Images of Guava_Good3
# 1 Images of Guava_Good4
# 1 Images of Guava_Good5
# 1 Images of Guava_Good6

# %%
print(f"{len(glob(Lime_Bad1))} Images of Lime_Bad1")
print(f"{len(glob(Lime_Bad2))} Images of Lime_Bad2")
print(f"{len(glob(Lime_Bad3))} Images of Lime_Bad3")
print(f"{len(glob(Lime_Bad4))} Images of Lime_Bad4")
print(f"{len(glob(Lime_Bad5))} Images of Lime_Bad5")
print(f"{len(glob(Lime_Bad6))} Images of Lime_Bad6")
# Out:
# 1 Images of Lime_Bad1
# 1 Images of Lime_Bad2
# 1 Images of Lime_Bad3
# 1 Images of Lime_Bad4
# 1 Images of Lime_Bad5
# 1 Images of Lime_Bad6

# %%
print(f"{len(glob(Lime_Good1))} Images of Lime_Good1")
print(f"{len(glob(Lime_Good2))} Images of Lime_Good2")
print(f"{len(glob(Lime_Good3))} Images of Lime_Good3")
print(f"{len(glob(Lime_Good4))} Images of Lime_Good4")
print(f"{len(glob(Lime_Good5))} Images of Lime_Good5")
print(f"{len(glob(Lime_Good6))} Images of Lime_Good6")
# Out:
# 1 Images of Lime_Good1
# 1 Images of Lime_Good2
# 1 Images of Lime_Good3
# 1 Images of Lime_Good4
# 1 Images of Lime_Good5
# 1 Images of Lime_Good6

# %%
print(f"{len(glob(Orange_Bad1))} Images of Orange_Bad1")
print(f"{len(glob(Orange_Bad2))} Images of Orange_Bad2")
print(f"{len(glob(Orange_Bad3))} Images of Orange_Bad3")
print(f"{len(glob(Orange_Bad4))} Images of Orange_Bad4")
print(f"{len(glob(Orange_Bad5))} Images of Orange_Bad5")
print(f"{len(glob(Orange_Bad6))} Images of Orange_Bad6")
# Out:
# 1 Images of Orange_Bad1
# 1 Images of Orange_Bad2
# 1 Images of Orange_Bad3
# 1 Images of Orange_Bad4
# 1 Images of Orange_Bad5
# 1 Images of Orange_Bad6

# %%
print(f"{len(glob(Orange_Good1))} Images of Orange_Good1")
print(f"{len(glob(Orange_Good2))} Images of Orange_Good2")
print(f"{len(glob(Orange_Good3))} Images of Orange_Good3")
print(f"{len(glob(Orange_Good4))} Images of Orange_Good4")
print(f"{len(glob(Orange_Good5))} Images of Orange_Good5")
print(f"{len(glob(Orange_Good6))} Images of Orange_Good6")
# Out:
# 1 Images of Orange_Good1
# 1 Images of Orange_Good2
# 1 Images of Orange_Good3
# 1 Images of Orange_Good4
# 1 Images of Orange_Good5
# 1 Images of Orange_Good6

# %%
print(f"{len(glob(Pomegranate_Bad1))} Images of Pomegranate_Bad1")
print(f"{len(glob(Pomegranate_Bad2))} Images of Pomegranate_Bad2")
print(f"{len(glob(Pomegranate_Bad3))} Images of Pomegranate_Bad3")
print(f"{len(glob(Pomegranate_Bad4))} Images of Pomegranate_Bad4")
print(f"{len(glob(Pomegranate_Bad5))} Images of Pomegranate_Bad5")
print(f"{len(glob(Pomegranate_Bad6))} Images of Pomegranate_Bad6")
# Out:
# 1 Images of Pomegranate_Bad1
# 1 Images of Pomegranate_Bad2
# 1 Images of Pomegranate_Bad3
# 1 Images of Pomegranate_Bad4
# 1 Images of Pomegranate_Bad5
# 1 Images of Pomegranate_Bad6

# %%
print(f"{len(glob(Pomegranate_Good1))} Images of Pomegranate_Good1")
print(f"{len(glob(Pomegranate_Good2))} Images of Pomegranate_Good2")
print(f"{len(glob(Pomegranate_Good3))} Images of Pomegranate_Good3")
print(f"{len(glob(Pomegranate_Good4))} Images of Pomegranate_Good4")
print(f"{len(glob(Pomegranate_Good5))} Images of Pomegranate_Good5")
print(f"{len(glob(Pomegranate_Good6))} Images of Pomegranate_Good6")
# Out:
# 1 Images of Pomegranate_Good1
# 1 Images of Pomegranate_Good2
# 1 Images of Pomegranate_Good3
# 1 Images of Pomegranate_Good4
# 1 Images of Pomegranate_Good5
# 1 Images of Pomegranate_Good6

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K

img_width, img_height = 256, 256

# %%
train_data_dir = '/home/manas/Desktop/ML/JU/Train'
validation_data_dir = '/home/manas/Desktop/ML/JU/Test'
nb_train_samples =400
nb_validation_samples = 100
epochs = 10
batch_size = 25

# %%
if K.image_data_format() == 'channels_first':
	input_shape = (3, img_width, img_height)
else:
	input_shape = (img_width, img_height, 3)

# %%
model = Sequential()
model.add(Conv2D(32, (2, 2), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))
# Out:
# 2022-08-22 01:19:01.264042: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-22 01:19:01.264451: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/manas/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-08-22 01:19:01.264510: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/manas/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:
# ...

# %%
model.compile(loss='binary_crossentropy',
			optimizer='rmsprop',
			metrics=['accuracy'])

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' # warning disabling

training_dataset = get_image_data(
    directory=path,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=(img_width, img_height),
    batch_size=batch_size
)

validation_dataset = get_image_data(
    directory=path,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=(img_width, img_height),
    batch_size=batch_size
)

class_names = training_dataset.class_names
print(class_names)
# Out:
# Found 19526 files belonging to 3 classes.
# Using 15621 files for training.
# Found 19526 files belonging to 3 classes.
# Using 3905 files for validation.
# ['Bad Quality_Fruits', 'Good Quality_Fruits', 'Mixed Qualit_Fruits']

# %%
batch_size = 25
plt.figure(figsize=(10, 10))
for images, labels in training_dataset.take(1):
    for i in range(batch_size):
        plt.subplot(5, 5, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
def configure_performant_datasets(dataset, shuffling=None):
    """ Custom function to prefetch and cache stored elements 
    of retrieved image data to boost latency and performance 
    at the cost of higher memory usage. """    
    AUTOTUNE = tf.data.AUTOTUNE
    # Cache and prefetch elements of input data for boosted performance
    if not shuffling:
        return dataset.cache().prefetch(buffer_size=AUTOTUNE)
    else:
        return dataset.cache().shuffle(shuffling).prefetch(buffer_size=AUTOTUNE)

# %%
training_dataset = configure_performant_datasets(training_dataset, 
                                                 shuffling=1000)
validation_dataset = configure_performant_datasets(validation_dataset)

# %%
resizing_layer = layers.experimental.preprocessing.Resizing(img_width, img_height)
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255, 
                                                                  input_shape=(img_width, img_height, 
                                                                               3))

# %%
input_layer = layers.InputLayer(input_shape=(img_width, img_height, 3))
flattening_layer = layers.Flatten() # 1-d array
dense_layer_1 = layers.Dense(128, activation="relu")
dense_layer_2 = layers.Dense(64, activation="relu")
output_layer = layers.Dense(1, activation='sigmoid')

NUM_CLASSES = 29

model = Sequential()

model.add(input_layer)
model.add(resizing_layer)
model.add(normalization_layer)
model.add(flattening_layer)
model.add(dense_layer_1)
model.add(dense_layer_2)
model.add(output_layer)

model.compile(
    optimizer="adam",
    loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=["accuracy"]
)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  resizing (Resizing)         (None, 256, 256, 3)       0
#
#  rescaling (Rescaling)       (None, 256, 256, 3)       0
#
#  flatten_1 (Flatten)         (None, 196608)            0
#
#  dense_2 (Dense)             (None, 128)               25165952
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dense_4 (Dense)             (None, 1)                 65
#
# ...
# Total params: 25,174,273
# Trainable params: 25,174,273
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 10

history_v1 = model.fit(
    training_dataset,
    validation_data=validation_dataset,
    epochs=epochs
)
# Out:
# Epoch 1/10
# 2022-08-22 01:25:57.004087: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 178 of 1000
# 2022-08-22 01:26:06.966883: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 341 of 1000
# 2022-08-22 01:26:16.857396: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 522 of 1000
#   1/625 [..............................] - ETA: 6:28:35 - loss: 0.8821 - accuracy: 0.2800
# 2022-08-22 01:26:23.759959: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:415] Shuffle buffer filled.
# 625/625 [==============================] - 129s 146ms/step - loss: 2.8790 - accuracy: 0.6589 - val_loss: 1.9652 - val_accuracy: 0.5803
# Epoch 2/10
# 625/625 [==============================] - 81s 130ms/step - loss: -0.7744 - accuracy: 0.6675 - val_loss: -12.9566 - val_accuracy: 0.5987
# Epoch 3/10
# ...

# %%
def plot_training_results(history):
    """
    Visualize results of the model training using `matplotlib`.

    The visualization will include charts for accuracy and loss, 
    on the training and as well as validation data sets.

    INPUTS:
        history(tf.keras.callbacks.History): 
            Contains data on how the model metrics changed 
            over the course of training.
    
    OUTPUTS: 
        None.
    """
    accuracy = history.history['accuracy']
    accuracy
    validation_accuracy = history.history['val_accuracy']
    validation_accuracy

    loss = history.history['loss']
    loss
    validation_loss = history.history['val_loss']
    validation_loss

    epochs_range = range(epochs)
    epochs_range

    plt.figure(figsize=(20, 8))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, accuracy, label='Training Accuracy')
    plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, validation_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
plot_training_results(history_v1)
